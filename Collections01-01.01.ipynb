# %%
idade1 = 39
idade2 = 30
idade3 = 27
idade4 = 18

print(idade1)
print(idade2)
print(idade3)
print(idade4)
# Out:
# 39
# 30
# 27
# 18

# %%
idades = [39, 30, 27, 15]

# %%
type(idades)
# Out:
# list

# %%
len(idades)
# Out:
# 4

# %%
idades[0]
# Out:
# 39

# %%
idades
# Out:
# [39, 30, 27, 15]

# %%
idades.append(16)

# %%
idades[4]
# Out:
# 16

# %%
for idade in idades:
  print(idade)
# Out:
# 39
# 30
# 27
# 15
# 16

# %%
idades.remove(30)

# %%
idades.append(15)

# %%
idades
# Out:
# [39, 27, 15, 16, 15]

# %%
idades.remove(15)

# %%
idades
# Out:
# [39, 27, 16, 15]

# %%
idades.append(27)
idades.remove(27)
idades
# Out:
# [39, 16, 15, 27]

# %%
28 in idades
# Out:
# False

# %%
15 in idades
# Out:
# True

# %%
if 15 in idades:
  idades.remove(15)

# %%
idades
# Out:
# [39, 16, 27]

# %%
if 28 in idades:
  idades.remove(28)

# %%
idades
# Out:
# [39, 16, 27]

# %%
idades.append(19)
idades
# Out:
# [39, 16, 27, 19]

# %%
idades.insert(0,64)
idades
# Out:
# [64, 39, 16, 27, 19]

# %%
idades = [26, 94, 36]
idades
# Out:
# [26, 94, 36]

# %%
idades.append([17, 82])

# %%
idades
# Out:
# [26, 94, 36, [17, 82]]

# %%
for elemento in idades:
  print('Recebi o elemento: ', elemento)
# Out:
# Recebi o elemento:  26
# Recebi o elemento:  94
# Recebi o elemento:  36
# Recebi o elemento:  [17, 82]

# %%
idades = [26, 94, 36]
idades.extend([17, 26])
idades
# Out:
# [26, 94, 36, 17, 26]

# %%
for idade in idades:
  print(idade + 1)
# Out:
# 27
# 95
# 37
# 18
# 27

# %%
idades_no_ano_que_vem = []
for idade in idades:
  idades_no_ano_que_vem.append(idade + 1)
idades_no_ano_que_vem
# Out:
# [27, 95, 37, 18, 27]

# %%
[(idade + 1) for idade in idades]
# Out:
# [27, 95, 37, 18, 27]

# %%
idades_no_ano_que_vem = [(idade + 1) for idade in idades]
idades_no_ano_que_vem
# Out:
# [27, 95, 37, 18, 27]

# %%
[(idade) for idade in idades if idade > 21]
# Out:
# [26, 94, 36, 26]

# %%
def proximo_ano(idade):
  return idade + 1

[proximo_ano(idade) for idade in idades if idade > 21]
# Out:
# [27, 95, 37, 27]

# %%
def faz_processamento_de_visualizacao(lista):
  print(len(lista))
  lista.append(13)

# %%
idades = [16, 25, 37, 24, 22]
faz_processamento_de_visualizacao(idades)
idades
# Out:
# 5
# [16, 25, 37, 24, 22, 13]

# %%
def faz_processamento_de_visualizacao(lista = []):
  print(len(lista))
  print(lista)
  lista.append(13)

# %%
faz_processamento_de_visualizacao()
# Out:
# 0
# []

# %%
faz_processamento_de_visualizacao()
# Out:
# 1
# [13]

# %%
def faz_processamento_de_visualizacao(lista = None):
  if lista == None:
    lista = list()
  print(len(lista))
  print(lista)
  lista.append(13)

# %%
faz_processamento_de_visualizacao()
faz_processamento_de_visualizacao()
# Out:
# 0
# []
# 0
# []
