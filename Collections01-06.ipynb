# %%
idades = [12, 23, 34, 45, 56, 67, 12, 78]

# %%
sorted(idades)
# Out:
# [12, 12, 23, 34, 45, 56, 67, 78]

# %%
list(reversed(idades))
# Out:
# [78, 12, 67, 56, 45, 34, 23, 12]

# %%
sorted(idades, reverse = True)
# Out:
# [78, 67, 56, 45, 34, 23, 12, 12]

# %%
idades
# Out:
# [12, 23, 34, 45, 56, 67, 12, 78]

# %%
idades.sort()

# %%
idades
# Out:
# [12, 12, 23, 34, 45, 56, 67, 78]
