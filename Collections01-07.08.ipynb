# %%
nomes = ['Nala', 'Io', 'Carol']
sorted(nomes)

# %%
class ContaSalario:

  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    if type(outro) != ContaSalario:
      return False
    return self._codigo == outro._codigo and self._saldo == outro._saldo

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>> Codigo {} Saldo {} <<]".format(self._codigo, self._saldo)

# %%
conta_da_nala = ContaSalario(17)
conta_da_nala.deposita(500)

conta_da_io = ContaSalario(3)
conta_da_io.deposita(1000)

conta_do_carol = ContaSalario(133)
conta_do_carol.deposita(510)

contas = [conta_da_nala, conta_da_io, conta_do_carol]

# %%
for conta in contas:
  print(conta)
# Out:
# [>> Codigo 17 Saldo 500 <<]
# [>> Codigo 3 Saldo 1000 <<]
# [>> Codigo 133 Saldo 510 <<]

# %%
conta_da_nala < conta_da_io
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-61aa901c8d56> in <cell line: 1>()
# ----> 1 conta_da_nala < conta_da_io
#
# TypeError: '<' not supported between instances of 'ContaSalario' and 'ContaSalario'

# %%
def extrai_saldo(conta):
  return conta._saldo

for conta in sorted(contas, key = extrai_saldo):
  print(conta)
# Out:
# [>> Codigo 17 Saldo 500 <<]
# [>> Codigo 133 Saldo 510 <<]
# [>> Codigo 3 Saldo 1000 <<]

# %%
from operator import attrgetter

for conta in sorted(contas, key = attrgetter('_saldo')):
  print(conta)
# Out:
# [>> Codigo 17 Saldo 500 <<]
# [>> Codigo 133 Saldo 510 <<]
# [>> Codigo 3 Saldo 1000 <<]

# %%
class ContaSalario:

  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    if type(outro) != ContaSalario:
      return False
    return self._codigo == outro._codigo and self._saldo == outro._saldo

  def __lt__(self, outro):
    return self._saldo < outro._saldo

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>> Codigo {} Saldo {} <<]".format(self._codigo, self._saldo)

# %%
conta_da_nala = ContaSalario(17)
conta_da_nala.deposita(500)

conta_da_io = ContaSalario(3)
conta_da_io.deposita(1000)

conta_do_carol = ContaSalario(133)
conta_do_carol.deposita(510)

contas = [conta_da_nala, conta_da_io, conta_do_carol]

# %%
conta_da_nala < conta_da_io
# Out:
# True

# %%
conta_da_nala < conta_da_io
# Out:
# True

# %%
for conta in sorted(contas, reverse = True):
  print(conta)
# Out:
# [>> Codigo 3 Saldo 1000 <<]
# [>> Codigo 133 Saldo 510 <<]
# [>> Codigo 17 Saldo 500 <<]

# %%
conta_da_nala = ContaSalario(17)
conta_da_nala.deposita(500)

conta_da_io = ContaSalario(3)
conta_da_io.deposita(1000)

conta_do_carol = ContaSalario(133)
conta_do_carol.deposita(500)

contas = [conta_da_nala, conta_da_io, conta_do_carol]

# %%
for conta in sorted(contas, key = attrgetter('_saldo', '_codigo')):
  print (conta)
# Out:
# [>> Codigo 17 Saldo 500 <<]
# [>> Codigo 133 Saldo 500 <<]
# [>> Codigo 3 Saldo 1000 <<]

# %%
conta_da_nala = ContaSalario(17)
conta_da_nala.deposita(500)

conta_da_io = ContaSalario(3)
conta_da_io.deposita(500)

conta_do_carol = ContaSalario(133)
conta_do_carol.deposita(500)

contas = [conta_da_nala, conta_da_io, conta_do_carol]

# %%
for conta in sorted(contas, key = attrgetter('_saldo', '_codigo')):
  print (conta)
# Out:
# [>> Codigo 3 Saldo 500 <<]
# [>> Codigo 17 Saldo 500 <<]
# [>> Codigo 133 Saldo 500 <<]

# %%
class ContaSalario:

  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    if type(outro) != ContaSalario:
      return False
    return self._codigo == outro._codigo and self._saldo == outro._saldo

  def __lt__(self, outro):
    if self._saldo != outro._saldo:
      return self._saldo < outro._saldo
    return self._codigo < outro._codigo

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>> Codigo {} Saldo {} <<]".format(self._codigo, self._saldo)

# %%
conta_da_nala = ContaSalario(17)
conta_da_nala.deposita(500)

conta_da_io = ContaSalario(3)
conta_da_io.deposita(500)

conta_do_carol = ContaSalario(133)
conta_do_carol.deposita(500)

contas = [conta_da_nala, conta_da_io, conta_do_carol]

# %%
for conta in sorted(contas):
  print(conta)
# Out:
# [>> Codigo 3 Saldo 500 <<]
# [>> Codigo 17 Saldo 500 <<]
# [>> Codigo 133 Saldo 500 <<]

# %%
conta_da_nala <= conta_da_io
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-975eb9069d5e> in <cell line: 1>()
# ----> 1 conta_da_nala <= conta_da_io
#
# TypeError: '<=' not supported between instances of 'ContaSalario' and 'ContaSalario'

# %%
from functools import total_ordering

@total_ordering
class ContaSalario:

  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    if type(outro) != ContaSalario:
      return False
    return self._codigo == outro._codigo and self._saldo == outro._saldo

  def __lt__(self, outro):
    if self._saldo != outro._saldo:
      return self._saldo < outro._saldo
    return self._codigo < outro._codigo

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>> Codigo {} Saldo {} <<]".format(self._codigo, self._saldo)

# %%
conta_da_nala = ContaSalario(17)
conta_da_nala.deposita(500)

conta_da_io = ContaSalario(3)
conta_da_io.deposita(1000)

conta_do_carol = ContaSalario(133)
conta_do_carol.deposita(500)

contas = [conta_da_nala, conta_da_io, conta_do_carol]

# %%
conta_da_nala <= conta_da_io
# Out:
# True

# %%
conta_da_nala <= conta_do_carol
# Out:
# True
