# %% [markdown]
# ### Objetos próprios

# %%
class ContaCorrente:

  def __init__(self, codigo):
    self.codigo = codigo
    self.saldo = 0

  def deposita(self, valor):
    self.saldo += valor

  def __str__(self):
    return '[>> Codigo {} Saldo {} <<]'.format(self.codigo, self.saldo)

# %%
conta_da_nala = ContaCorrente(15)
print(conta_da_nala)
# Out:
# [>> Codigo 15 Saldo 0 <<]

# %%
conta_da_nala.deposita(254)
print(conta_da_nala)
# Out:
# [>> Codigo 15 Saldo 254 <<]

# %%
conta_da_carol = ContaCorrente(6253)
conta_da_carol.deposita(10)
print(conta_da_carol)
# Out:
# [>> Codigo 6253 Saldo 10 <<]

# %%
contas = [conta_da_nala, conta_da_carol]

# %%
print(contas)
# Out:
# [<__main__.ContaCorrente object at 0x790e848695d0>, <__main__.ContaCorrente object at 0x790e8486b910>]

# %%
for conta in contas:
  print(conta)
# Out:
# [>> Codigo 15 Saldo 254 <<]
# [>> Codigo 6253 Saldo 10 <<]

# %%
contas = [conta_da_nala, conta_da_carol, conta_da_nala]

# %%
print(contas[0])
# Out:
# [>> Codigo 15 Saldo 254 <<]

# %%
conta_da_nala.deposita(46)

# %%
print(contas[0])
# Out:
# [>> Codigo 15 Saldo 300 <<]

# %%
print(conta_da_nala)
# Out:
# [>> Codigo 15 Saldo 300 <<]

# %%
print(contas[2])
# Out:
# [>> Codigo 15 Saldo 300 <<]

# %%
def deposita_para_todas(contas):
  for conta in contas:
    conta.deposita(100)

contas = [conta_da_nala, conta_da_carol]
print(contas[0], contas[1])
deposita_para_todas(contas)
print(contas[0], contas[1])
# Out:
# [>> Codigo 15 Saldo 300 <<] [>> Codigo 6253 Saldo 10 <<]
# [>> Codigo 15 Saldo 400 <<] [>> Codigo 6253 Saldo 110 <<]

# %%
contas.insert(0, 77)
print(contas[0], contas[1], contas[2])
# Out:
# 77 [>> Codigo 15 Saldo 400 <<] [>> Codigo 6253 Saldo 110 <<]

# %%
deposita_para_todas(contas)
print(contas[0], contas[1], contas[2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-92ac4487eece> in <cell line: 1>()
# ----> 1 deposita_para_todas(contas)
#       2 print(contas[0], contas[1], contas[2])
#
# <ipython-input-16-d34983e3b078> in deposita_para_todas(contas)
#       1 def deposita_para_todas(contas):
#       2   for conta in contas:
# ----> 3     conta.deposita(100)
#       4
#       5 contas = [conta_da_nala, conta_da_carol]
#
# AttributeError: 'int' object has no attribute 'deposita'

# %%
['Nala', 2]
['Carol', 14]
# Out:
# ['Carol', 14]

# %%
nala = ('Nala', 2, 2021)   #tupla
carol = ('Carol', 14, 2009)

# %%
nala.append(73636)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-4293b271ed64> in <cell line: 1>()
# ----> 1 nala.append(73636)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
conta_da_nala = (15, 300)

conta_da_nala[1]
# Out:
# 300

# %%
def deposita(conta):
  novo_saldo = conta[1] + 100
  codigo = conta[0]
  return (codigo, novo_saldo)

# %%
deposita(conta_da_nala)
# Out:
# (15, 400)

# %%
conta_da_nala
# Out:
# (15, 300)

# %%
conta_da_nala = deposita(conta_da_nala)
conta_da_nala
# Out:
# (15, 400)

# %%
usuarios = [nala, carol]
usuarios
# Out:
# [('Nala', 2, 2021), ('Carol', 14, 2009)]

# %%
usuarios.append(('Io', 22, 2001))

# %%
usuarios
# Out:
# [('Nala', 2, 2021), ('Carol', 14, 2009), ('Io', 22, 2001)]

# %%
usuarios[0][0] = 'pão'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-d7c6682f1338> in <cell line: 1>()
# ----> 1 usuarios[0][0] = 'pão'
#
# TypeError: 'tuple' object does not support item assignment

# %%
conta_da_nala = ContaCorrente(15)
conta_da_nala.deposita(1999)
conta_da_carol = ContaCorrente(263)
conta_da_carol.deposita(263)

contas = (conta_da_nala, conta_da_carol)

# %%
for conta in contas:
  print(conta)
# Out:
# [>> Codigo 15 Saldo 1999 <<]
# [>> Codigo 263 Saldo 263 <<]

# %%
contas[0].deposita(300)

# %%
for conta in contas:
  print(conta)
# Out:
# [>> Codigo 15 Saldo 2299 <<]
# [>> Codigo 263 Saldo 263 <<]
